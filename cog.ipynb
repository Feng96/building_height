# %%
import pystac_client
import planetary_computer
import rasterio
import leafmap
import geopandas as gpd

client = pystac_client.Client.open(
    "https://planetarycomputer.microsoft.com/api/stac/v1",
    modifier=planetary_computer.sign_inplace,
)

# %%
time_range = "2012-01-01/2020-12-31"
bbox = [-84.271532,35.79608,-83.66853,36.186094]

# %%
collections = ["3dep-lidar-hag"]
search = client.search(
    collections=collections,
    bbox = bbox,
    datetime=time_range)

items = search.get_all_items()
len(items)
# Out:
# 122

# %%
import geopandas

df = geopandas.GeoDataFrame.from_features(items.to_dict(), crs="epsg:4326")
df
# Out:
#                                               geometry datetime proj:epsg  \
# 0    POLYGON ((-84.23507 36.24564, -84.23767 36.171...     None      None
# 1    POLYGON ((-84.23767 36.17187, -84.24026 36.098...     None      None
# 2    POLYGON ((-84.24025 36.09809, -84.24283 36.024...     None      None
# 3    POLYGON ((-84.24283 36.02432, -84.24540 35.950...     None      None
# 4    POLYGON ((-84.24540 35.95055, -84.24668 35.913...     None      None
# ..                                                 ...      ...       ...
# 117  POLYGON ((-84.05246 36.25429, -84.05523 36.180...     None      None
# 118  POLYGON ((-84.15155 36.03520, -84.15421 35.961...     None      None
# 119  POLYGON ((-84.14889 36.10897, -84.15155 36.035...     None      None
# 120  POLYGON ((-84.14622 36.18273, -84.14889 36.108...     None      None
# 121  POLYGON ((-84.14353 36.25650, -84.14622 36.182...     None      None
#
#        proj:shape                             3dep:usgs_id  \
# ...

# %%
selected_item = items[0]

# %%
url = selected_item.assets["data"].href
url
# Out:
# 'https://usgslidareuwest.blob.core.windows.net/usgs-3dep-cogs/usgs-cogs/USGS_LPC_TN_27County_blk1_2015_LAS_2018/hag/USGS_LPC_TN_27County_blk1_2015_LAS_2018-hag-2m-9-6.tif?st=2023-04-11T18%3A07%3A18Z&se=2023-04-12T18%3A52%3A18Z&sp=rl&sv=2021-06-08&sr=c&skoid=c85c15d6-d1ae-42d4-af60-e2ca0f81359b&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2023-04-12T16%3A40%3A27Z&ske=2023-04-19T16%3A40%3A27Z&sks=b&skv=2021-06-08&sig=%2BjuABRAMOsgozJe4wxKBeDfA5N3gv5UsJg7JHh7NZMU%3D'

# %%
import wget

# %%
for i in range(13,len(items)):
    selected_item = items[i]
    url = selected_item.assets["data"].href
    export_address = f'C:/Users/utkge/Desktop/data/usgs3dep/knox/' + 'knox' + f'{i+1}' + '.tif'
    wget.download(url, export_address)
